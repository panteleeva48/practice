# %%
import os
import re
main_dir = '/Users/irene/Downloads/exam2017'
files_list = []
anns = []
for root, dirs, files in os.walk(main_dir):
    for name in files:
        if '.txt' in name:
            files_list.append(os.path.join(root, name))
        if '.ann' in name:
            anns.append(os.path.join(root, name))

# %%
d = {'EGe': 0, 'OBy': 0, 'VSa': 0, 'DPe': 0, 'ABl': 0, 'NMya': 0, 'Troshina': 0, 'NChe': 0, 'AKo': 0, 'JSl': 0, 'TroshinaK': 0, 'ABL': 0, 'ObY': 0, 'Oby': 0}

# %%
d
# Out:
# {'ABL': 0,
#  'ABl': 0,
#  'AKo': 0,
#  'DPe': 0,
#  'EGe': 0,
#  'JSl': 0,
#  'NChe': 0,
#  'NMya': 0,
#  'OBy': 0,
#  'ObY': 0,
#  'Oby': 0,
#  'Troshina': 0,
#  'TroshinaK': 0,
#  'VSa': 0}

# %%
files_list[0]
# Out:
# '/Users/irene/Downloads/exam2017/10_Troshina.txt'

# %%
files_list[1]
# Out:
# '/Users/irene/Downloads/exam2017/11_Troshina.txt'

# %%
for s in files_list[0:2]:
    name = re.search('/Users/irene/Downloads/exam2017/(.+?).txt', s).group(1)
    name = re.sub('[0-9_]', '', name)
    with open(s, 'r') as f:
        text = f.read()
        length = len(text.split())
        d[name] += length

# %%
d
# Out:
# {'ABL': 0,
#  'ABl': 0,
#  'AKo': 0,
#  'DPe': 0,
#  'EGe': 0,
#  'JSl': 0,
#  'NChe': 0,
#  'NMya': 0,
#  'OBy': 0,
#  'ObY': 0,
#  'Oby': 0,
#  'Troshina': 396,
#  'TroshinaK': 0,
#  'VSa': 0}

# %%
print('Количество эссе:', len(anns))
# Out:
# Количество эссе: 1572

# %%
anns[0]
# Out:
# '/Users/irene/Downloads/exam2017/10_Troshina.ann'

# %%
names = []
for ann in anns:
    #print(ann)
    name = re.search('/Users/irene/Downloads/exam2017/(.+?).ann', ann).group(1)
    name = re.sub('[0-9_]', '', name)
    names.append(name)

# %%
import collections
counter=collections.Counter(names)
print(counter)
# Out:
# Counter({'EGe': 542, 'OBy': 377, 'VSa': 276, 'DPe': 164, 'ABl': 99, 'NMya': 62, 'Troshina': 20, 'NChe': 20, 'AKo': 4, 'JSl': 4, 'TroshinaK': 1, 'ABL': 1, 'ObY': 1, 'Oby': 1})

# %%
import re
import sys
if sys.version_info[0] < 3: 
    from StringIO import StringIO
else:
    from io import StringIO
import pandas as pd
import os
from model import Model
from langdetect import detect

model = Model('english-partut-ud-2.0-170801.udpipe')
def create_df_from_conllu(conllu):
    conllu = re.sub('# .+?\n', '', conllu)
    l = conllu.split('\n')
    string = 'Id\tForm\tLemma\tUPosTag\tXPosTag\tFeats\tHead\tDepRel\tDeps\tMisc\n'
    string += "\n".join(l)
    TESTDATA = StringIO(string)
    df = pd.read_csv(TESTDATA, sep="\t")
    return df


def delete_from_df(df):
    to_drop = []
    for index, row in df.iterrows():
        if '-' in str(row['Id']):
            num = len(row['Id'].split('-'))
            for x in range(num):
                if num != 0:
                    to_drop.append(index + num)
                    num -= 1
    return to_drop


def parsing(text):
    sentences = model.tokenize(text)
    for s in sentences:
        model.tag(s)
        model.parse(s)
    conllu = model.write(sentences, "conllu")
    return conllu


def open_ann_find_end(ann):
    ts = re.findall('\n(T[0-9]+)\t', ann)
    ts = sorted([int(t[1:]) for t in ts])
    grids = re.findall('\n(#[0-9]+)\t', ann)
    grids = sorted([int(grid[1:]) for grid in grids])
    if grids == [] and ts != []:
        return ts[-1]+1, 1
    elif grids != [] and ts == []:
        return 1, grids[-1]+1
    elif grids == [] and ts == []:
        return 1, 1
    else:
        return ts[-1]+1, grids[-1]+1
    
    
def opening(path):
    with open(path, 'r') as f:
        text = f.read()
    if '\ufeff' in text:
        text = re.sub('\n', '\r\n', text)
    return text


def df_changing(text):
    conllu = parsing(text)
    df = create_df_from_conllu(conllu)
    to_drop = delete_from_df(df)
    df = df.drop(df.index[to_drop])
    return df

def start_end(df, text):
    starts = []
    ends = []
    end = 0
    for index, row in df.iterrows():
        form = row['Form']
        #print(form)
        start = end + text.find(form)
        end = start + len(form)
        text = text[text.find(form)+len(form):]
        #print(form, start, end)
        starts.append(start)
        ends.append(end)
    return starts, ends


def add_ann(ann, df, t, grid):
    strings_in_file = []
    tx = ann
    for index, row in df.iterrows():
        s1 = 'T' + str(t) + '\t' + str(row['UPosTag']) + ' ' + str(row['START']) + ' ' + str(row['END']) + '\t' + str(row['Form']) + '\n'
        s2 = '#'+ str(grid) + '\tAnnotatorNotes T' + str(t) + "\tlemma = '" + str(row['Lemma']) + "'\n"
        tx += s1 + s2
        t += 1
        grid += 1
    return tx

def itog(path_txt):
    file_name = re.search('(.+/.+?).txt', path_txt).group(1)
    ann = opening(file_name + '.ann')
    text = opening(path_txt)
    if detect(text) == 'en':
        df = df_changing(text)
        t, grid = open_ann_find_end(ann)
        starts, ends = start_end(df, text)
        df['START'] = starts
        df['END'] = ends
        return starts[-1], ends[-1]

# %%
anns[0]
# Out:
# '/Users/irene/Downloads/exam2017/10_Troshina.ann'

# %%
files_list[0]
# Out:
# '/Users/irene/Downloads/exam2017/10_Troshina.txt'

# %%
itog(files_list[0])
# Out:
# (441, 442)

# %%
without_ann = []
annots = []
for ann in anns:
    gett = []
    with open(ann) as f:
        ls = f.readlines()
        for k in ls:
            if 'note' in k:
                num = re.search('(T.+?)\t', k).group(1)
                gett.append(num)
        if gett != []:
            last = gett[-1]
            for z in ls:
                if 'AnnotatorNotes '+last+'\t' in z and 'lemma' not in z and 'незаконченное' not in z and 'лучше' not in z and 'note' not in z and 'essay' not in z and 'It' not in z and 'ДАЙТЕ' not in z:
                    #print(z)
                    annot = re.search('AnnotatorNotes '+last+'\t(.+)',z).group(1)
                    print(annot)
                    annots.append(annot)
        else:
            without_ann.append(ann)
            #print(ann)
# Out:
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# ABl
# F. Baykov
# F. Baykov
# F. Baykov
# F. Baykov
# F. Baykov
# F. Baykov
# F. Baykov
# F. Baykov
# F. Baykov
# Разметил Ф. Байков
# Разметил Ф. Байков
# Разметил Ф. Байков
# Разметил Ф. Байков
# Ф. Байков
# Ф. Байков
# Ф. Байков
# Bayarsaikhan N.
# Bayarsaikhan N.
# DBa+ABl
# F. Baykov
# F. Baykov
# F. Baykov
# F. Baykov
# Bayarsaikhan N.
# F. Baykov
# Bayarsaikhan N.
# Oleynik
# Bayarsaikhan N.
# Oleynik
# Oleynik
# Bayarsaikhan N.
# F. Baykov
# Oleynik
# F. Baykov
# Oleynik
# Oleynik
# Vlad Muntyan
# F. Baykov
# Oleynik
# F. Baykov
# Натаров
# Oleynik
# Oleynik
# Vlad Muntyan
# Oleynik
# Maltseva Rimma
# Oleynik
# Oleynik
# Oleynik
# Oleynik
# Oleynik
# Kotiev
# Oleynik
# Oleynik
# Maltseva Rimma
# Maltseva Rimma
# DBatov
# Maltseva Rimma
# Maltseva Rimma
# Maltseva Rimma
# Maltseva Rimma
# Oleynik
# DBatov
# Maltseva Rimma
# Maltseva Rimma
# Oleynik
# DBatov
# DBatov
# Maltseva Rimma
# Oleynik
# Maltseva Rimma
# Maltseva Rimma
# DBatov
# Oleynik
# Maltseva Rimma
# Maltseva Rimma
# Maltseva Rimma
# Oleynik
# DBatov
# DBatov
# DBatov
# DBatov
# DBatov
# DBatov
# DBatov
# DBatov
# DBatov
# DBatov
# Maltseva Rimma
# DBatov
# DBatov
# DBatov
# DBatov
# DBatov
# DBatov
# DBatov
# DBatov
# DBatov
# DBatov
# DBatov
# DBatov
# DBatov
# DBatov
# DBatov
# DBatov
# DBatov
# DBatov
# DBatov
# DBatov
# DBatov
# DBatov
# DBatov
# DBatov
# DBatov
# DBatov
# F. Baykov
# DBatov
# DBatov
# DBatov
# DBatov
# F. Baykov
# F. Baykov
# DBatov
# DBatov
# DBatov
# DBatov
# DBatov
# DBatov
# DBatov
# DBatov
# DBatov
# DBatov
# DBatov
# Легась А.В
# DBatov
# DBatov
# F. Baykov
# DBatov
# DBatov
# Zavyalov
# Zavyalov
# Zavyalov
# Zavyalov
# F. Baykov
# Zavyalov
# Zavyalov
# Zavyalov
# DBatov
# Zavyalov
# DBatov
# Zavyalov
# DBatov
# Zavyalov
# Легась А.В
# DBatov
# Zavyalov
# Zavyalov
# DBatov
# Zavyalov
# DBatov
# Zavyalov
# DBatov
# Zavyalov
# F. Baykov
# Zavyalov
# F. Baykov
# Zavyalov
# F. Baykov
# DBatov
# DBatov
# DBatov
# DBatov
# DBatov
# DBatov
# DBatov
# Zavyalov
# Zavyalov
# Zavyalov
# F. Baykov
# Zavyalov
# Zavyalov
# Zavyalov
# Zavyalov
# DBatov
# DBatov
# Zavyalov
# Zavyalov
# Zavyalov
# F. Baykov
# Zavyalov
# Zavyalov
# Zavyalov
# Zavyalov
# Zavyalov
# Zavyalov
# Zavyalov
# Zavyalov
# Zavyalov
# Zavyalov
# Zavyalov
# F. Baykov
# DBatov
# DBatov
# DBatov
# DBatov
# Vlad Muntyan
# F. Baykov
# DBatov
# DBatov
# DBatov
# DBatov
# Zavyalov
# Zavyalov
# Zavyalov
# Zavyalov
# Zavyalov
# Zavyalov
# Zavyalov
# Zavyalov
# Zavyalov
# Zavyalov
# Zavyalov
# F. Baykov
# DBatov
# DBatov
# F. Baykov
# Zavyalov
# Vlad Muntyan
# DBatov
# DBatov
# DBatov
# DBatov
# DBatov
# DBatov
# DBatov
# Zavyalov
# F. Baykov
# Zavyalov
# Zavyalov
# Zavyalov
# Zavyalov
# Zavyalov
# Zavyalov
# Zavyalov
# F. Baykov
# Zavyalov
# Zavyalov
# Zavyalov
# F. Baykov
# DBatov
# DBatov
# DBatov
# DBatov
# Vlad Muntyan
# F. Baykov
# F. Baykov
# DBatov
# DBatov
# DBatov
# DBatov
# DBatov
# DBatov
# DBatov
# DBatov
# DBatov
# DBatov
# DBatov
# DBatov
# DBatov
# DBatov
# F. Baykov
# Zavyalov
# Zavyalov
# Zavyalov
# F. Baykov
# Zavyalov
# Zavyalov
# Zavyalov
# F. Baykov
# Zavyalov
# Zavyalov
# Zavyalov
# Zavyalov
# Zavyalov
# Zavyalov
# Zavyalov
# F. Baykov
# Zavyalov
# Oleynik
# Oleynik
# The Shawshank Redemption
# Oleynik
# Oleynik
# Oleynik
# Oleynik
# Oleynik
# Oleynik
# Oleynik
# Oleynik
# Oleynik
# Oleynik
# Oleynik
# Oleynik
# Oleynik
# Oleynik
# Oleynik
# Oleynik
# Oleynik
# F. Baykov
# F. Baykov
# Oleynik
# Oleynik
# Oleynik
# F. Baykov
# F. Baykov
# F. Baykov
# F. Baykov
# F. Baykov
# F. Baykov
# F. Baykov
# F. Baykov
# F. Baykov
# F. Baykov
# F. Baykov
# F. Baykov
# F. Baykov
# F. Baykov
# F. Baykov
# F. Baykov
# F. Baykov
# F. Baykov
# F. Baykov
# F. Baykov
# F. Baykov
# F. Baykov
# F. Baykov
# Oleynik
# Oleynik
# Oleynik
# F. Baykov
# Oleynik
# Oleynik
# Oleynik
# Oleynik
# F. Baykov
# F. Baykov
# Oleynik
# Oleynik
# Oleynik
# Oleynik
# Oleynik
# Пархоменко
# Пархоменко
# Oleynik
# Пархоменко
# Oleynik
# DBatov
# DBatov
# Oleynik
# Oleynik
# Пархоменко
# Oleynik
# Пархоменко
# DBatov
# DBatov
# Oleynik
# DBatov
# F. Baykov
# larionova
# Larionova
# Пархоменко
# Пархоменко
# Larionova
# Пархоменко
# Натаров
# Легась А.В
# Легась А.В
# Valeria Fedorova
# Легась А.В
# Натаров
# Легась А.В
# Натаров
# Натаров
# НБаярсайхан
# ВФЕДОРОВА
# Fedorova Valeria
# Fedorova Valeria
# Fedorova Valeria
# F. Baykov
# Zavyalov
# F. Baykov
# SG
# F. Baykov
# F. Baykov
# F. Baykov
# F. Baykov
# F. Baykov
# F. Baykov
# F. Baykov
# F. Baykov
# F. Baykov
# F. Baykov
# F. Baykov
# F. Baykov
# F. Baykov
# F. Baykov
# Zavyalov
# Zavyalov
# Zavyalov
# Zavyalov
# Zavyalov
# Zavyalov
# Zavyalov
# Zavyalov
# Zavyalov
# Zavyalov
# Zavyalov
# Zavyalov
# Zavyalov
# F. Baykov
# F. Baykov
# F. Baykov
# A. Orlenko
# A. Orlenko
# A. Orlenko
# F. Baykov
# F. Baykov
# F. Baykov
# F. Baykov
# A. Orlenko
# F. Baykov
# F. Baykov
# F. Baykov
# F. Baykov
# F. Baykov
# SP
# F. Baykov
# A. Orlenko
# F. Baykov
# A. Orlenko
# A. Orlenko
# F. Baykov
# F. Baykov
# F. Baykov
# F. Baykov
# F. Baykov
# F. Baykov
# F. Baykov
# F. Baykov
# A. Orlenko
# F. Baykov
# F. Baykov
# F. Baykov
# F. Baykov
# F. Baykov
# F. Baykov
# F. Baykov
# F. Baykov
# F. Baykov
# F. Baykov
# F. Baykov
# F. Baykov
# F. Baykov
# F. Baykov
# F. Baykov
# F. Baykov
# A. Orlenko
# F. Baykov
# Oleynik
# F. Baykov
# A. Orlenko
# F. Baykov
# Oleynik
# Oleynik
# Oleynik
# Oleynik
# Oleynik
# A. Orlenko
# Oleynik
# Zavyalov
# F. Baykov
# A. Orlenko
# F. Baykov
# Zavyalov
# Zavyalov
# Zavyalov
# Oleynik
# Zavyalov
# A. Orlenko
# Zavyalov
# Zavyalov
# Zavyalov
# A. Orlenko
# A. Orlenko
# Zavyalov
# Zavyalov
# Zavyalov
# Zavyalov
# Zavyalov
# Zavyalov
# Zavyalov
# Zavyalov
# Zavyalov
# Zavyalov
# A. Orlenko
# Zavyalov
# Zavyalov
# Oleynik
# Oleynik
# Zavyalov
# Oleynik
# Zavyalov
# A. Orlenko
# Oleynik
# Oleynik
# Oleynik
# Zavyalov
# Oleynik
# Zavyalov
# Oleynik
# Zavyalov
# Oleynik
# Zavyalov
# Oleynik
# Zavyalov
# Oleynik
# Oleynik
# Oleynik
# Zavyalov
# Oleynik
# Oleynik
# Zavyalov
# Oleynik
# Zavyalov
# Oleynik
# Zavyalov
# Oleynik
# A. Orlenko
# Oleynik
# Zavyalov
# Oleynik
# Zavyalov
# Oleynik
# Zavyalov
# Oleynik
# Oleynik
# Zavyalov
# Oleynik
# Oleynik
# Oleynik
# Oleynik
# Zavyalov
# Zavyalov
# Zavyalov
# Zavyalov
# Oleynik
# Oleynik
# Zavyalov
# Zavyalov
# Zavyalov
# Zavyalov
# A. Orlenko
# Oleynik

# %%
import collections
counter=collections.Counter(annots)
print(counter)
# Out:
# Counter({'Zavyalov': 132, 'F. Baykov': 129, 'DBatov': 116, 'Oleynik': 100, 'ABl': 95, 'A. Orlenko': 19, 'Maltseva Rimma ': 15, 'Пархоменко': 8, 'Bayarsaikhan N.': 6, 'Легась А.В': 6, 'Vlad Muntyan': 5, 'Натаров': 5, 'Разметил Ф. Байков': 4, 'Ф. Байков': 3, 'Fedorova Valeria': 3, 'Larionova': 2, 'DBa+ABl': 1, 'Kotiev': 1, 'Maltseva Rimma': 1, 'The Shawshank Redemption': 1, 'larionova': 1, 'Valeria Fedorova': 1, 'НБаярсайхан': 1, 'ВФЕДОРОВА': 1, 'SG': 1, 'SP': 1})
